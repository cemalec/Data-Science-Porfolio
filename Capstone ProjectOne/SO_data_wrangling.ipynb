# %% [markdown]
# ## Data Wrangling
#
# source of data: https://nces.ed.gov/EDAT/Data/Zip/HSLS_2016_v1_0_CSV_Datasets.zip
#
# source of layout data: https://nces.ed.gov/EDAT/Data/Zip/HSLS_2016_v1_0_CodeBook_Layout.zip

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The csv file is quite large, but not so large that it can't fit in memory, however, it fits in much more easily if we take away some of the columns that won't be useful to the analysis right away. These include columns that are suppressed for public use due to privacy concerns, columns that include statistical weights used to create accurate aggregates of the data, and columns indicating where values have been imputed.
#
# Though these other columns, particularly the weights, will be used later, here we initially only extract the data columns so that we can read in a table in a reasonable amount of time.

# %%
#create variables for file locations
filepath = '/Users/chrismalec/Documents/Springboard/CapstoneProjectOne/'
studentdatafile = 'HSLS_2016_v1_0_CSV_Datasets/hsls_16_student_v1_0.csv'
studentcodebookfile = 'HSLS_2016_v1_0_CodeBook_Layout/Layout_STUDENT.txt'
schooldatafile = 'HSLS_2016_v1_0_CSV_Datasets/hsls_09_school_v1_0.csv'
#import a small sample of the file
with open(filepath+studentdatafile) as file:
    student_df = pd.read_csv(file,nrows = 10)
    file.close()

#Remove columns with '-5' and create list of column names removed.
#Create separate list of columns for weighting and imputation.
#The remaining columns will constitute the database.
student_suppressed_columns = []
student_weight_columns = []
student_imputed_columns = []
student_columns = []
for column in student_df.columns:
    if (student_df[column] == -5).all():
        student_suppressed_columns.append(column)
    elif column[0] == 'W':
        student_weight_columns.append(column)
    elif column[-2:] == 'IM':
        student_imputed_columns.append(column)
    else:
        student_columns.append(column)

# %%
#Import the selected columns from the file for all rows.
with open(filepath+studentdatafile) as file:
    student_df = pd.read_csv(file,usecols = student_columns)
    file.close()

# %% [markdown]
# There are several variables that indicate the students' dropout status and whether or not they have ever dropped out. This variable was chosen as the label because it indicated the outcome of the student as stated on their transcript four years after the ninth grade study. Other columns may be removed later due to high (trivial) correlation with the label.

# %%
#Create series of labels and remove it from the dataframe.
labels = student_df.pop('X3TOUTCOME')

# %% [markdown]
# As the project moves forward, it will be convenient to easily move between the numbers that denote various responses to the surveys and the human readable responses that the number represent. For example, the column 'S1ABILITYBA' represents a response to whether the '9th grader thinks he/she has the ability to complete a Bachelor's degree.' The possible answers are coded in the data table as 1,2,3,4,-8, and -9 which correspond to "Definitely not", "Probably not", "Probably", "Definitely", "Unit non-response", and "Missing."
#
# I create a dictionary from the documentation so that I can type student_value_labels['S1ABILITYBA']['4'] and obtain "Definitely" for use as a label in a graph or figure. Similarly, I include the description of the variable under the key 'desc'.

# %%
#create dictionary from the student codebook
#Start creating dictionary.
student_value_labels = {}
coded_columns = student_columns + student_imputed_columns + [labels.name]
with open(filepath+studentcodebookfile,'r') as file:
    #Reads file until it reaches the descriptions
    for line in file:
        if '/* Variable Names, Locations, and Descriptions */' in line:
            break
    
    #Takes first ASCII column and associates it with a data column
    for line in file:
        if len(line.split()) > 0:
            new_key = line.split()[0].strip()
        
        #places description in dictionary under 'desc'
        #reads until the value labels are reached
        if new_key in coded_columns:
            student_value_labels[new_key]={}
            desc = ' '.join(line.split()[2:])
            student_value_labels[new_key]['desc'] = desc
        elif '/* Variable Value Labels */' in line:
            break
        else:
            continue
    
    #key places additional key value pairs to specify the response associated with the number in the data table.       
    for line in file:
        if line.strip() in student_value_labels.keys():
            key = line.strip()
        #this comes up for some reason, not sure why there is a column or two that has no description but has a value mapping.
        elif line.strip() in coded_columns:
            key = line.strip()
            student_value_labels[key]={}
        elif line.strip()[:2] == '-5':
            continue
        elif line.strip() in student_suppressed_columns:
            continue
        elif line.strip() in student_weight_columns:
            continue
        #unambiguous end of file
        elif line == '':
            break
        else:
            key_value = line.split('=')
            student_value_labels[key][key_value[0].strip()] = key_value[1].strip()
file.close()

# %% [markdown]
# All negative numbers are missing data. The different values denote reasons for that the data is missing, which I can load from the original data if it turns out to be useful. I replace them with an nan value to assist in future data operations.

# %%
#replace negative numbers with nan
student_df = student_df.replace([x for x in range(-9,0)],np.nan)

print('There are '+str(student_df.isna().values.sum())+' out of '+str(student_df.size)+' missing values in the dataframe.')
print('The dataframe contains '+str(student_df.shape[1])+' features and '+str(student_df.shape[0])+' observations.')
# Out:
# There are 24183783 out of 63904657 missing values in the dataframe.
# The dataframe contains 2719 features and 23503 observations.

# %% [markdown]
# The data in the table is from several sources, and four different collection times. The first two letters in each column name specify the source of the data and the collection time of the data.  So as not to mix time periods, it may be useful to split the dataframe into four dataframes that contain data from the four collection times. After all, I don't want to imply that something that happened in a student's post-secondary career affected their decision to drop out in high school.
#
# First character code:
# Composite variables = X
# Student = S
# Parent = P
# Mathematics teacher = M
# Science teacher = N
# Administrator = A
# Counselor = C
# Weights = W
#
# Second character code:
# Base Year = 1
# First Followup = 2
# Second Followup = 3
# Third Followup = 4

# %%
#create logical masks to separate tables based on time
mask_BY = [(x[1]=='1')| (x=='STU_ID') for x in student_df.columns]
mask_F1 = [x[1]=='2' for x in student_df.columns]
mask_F2 = [x[1]=='3' for x in student_df.columns]
mask_F3 = [x[1]=='4' for x in student_df.columns]

#slice original table into four separate tables.
df_BY = student_df.loc[:,mask_BY]
df_F1 = student_df.loc[:,mask_F1]
df_F2 = student_df.loc[:,mask_F2]
df_F3 = student_df.loc[:,mask_F3]

# %%
#Store pickled versions of the dataframes locally so I don't have to redo this every time.
df_BY.to_pickle(filepath+'df_BY')
df_F1.to_pickle(filepath+'df_F1')
df_F2.to_pickle(filepath+'df_F2')
df_F3.to_pickle(filepath+'df_F3')

# %%
#Import the selected columns from the file for all rows.
with open(filepath+studentdatafile) as file:
    weights_df = pd.read_csv(file,usecols = student_weight_columns)
    file.close()

# %%
with open(filepath+schooldatafile) as file:
    school_df = pd.read_csv(file)
    file.close()
school_columns = school_df.columns

# %%
school_student_columns = []
for column in school_columns:
    if column in student_columns:
        school_student_columns.append(column)

# %%
sch_stu_df = df_BY.loc[:,['STU_ID']+school_student_columns].groupby(['X1AQDATE','X1CQDATE']).count()
school_df
# Out:
#      Sch_ID  X1NCESID    W1SCHOOL  STRAT_ID  PSU  X1CONTROL  X1LOCALE  \
# 0      1001        -5    2.331907        -5   -5          1         1
# 1      1002        -5    4.615802        -5   -5          1         2
# 2      1003        -5    8.810384        -5   -5          1         1
# 3      1004        -5    8.845971        -5   -5          2         2
# 4      1005        -5   10.807970        -5   -5          1         2
# 5      1006        -5   10.023618        -5   -5          1         2
# 6      1007        -5    5.390407        -5   -5          1         1
# 7      1008        -5    7.657878        -5   -5          1         1
# 8      1009        -5   21.281653        -5   -5          2         3
# 9      1010        -5    6.015197        -5   -5          1         3
# 10     1011        -5   12.185452        -5   -5          1         3
# 11     1012        -5   16.045157        -5   -5          1         2
# 12     1013        -5   39.903004        -5   -5          1         3
# 13     1014        -5   19.567742        -5   -5          1         4
# 14     1015        -5    7.524761        -5   -5          1         3
# 15     1016        -5   25.043599        -5   -5          1         1
# 16     1017        -5    3.063323        -5   -5          1         2
# 17     1018        -5   12.409731        -5   -5          2         2
# 18     1019        -5    5.537254        -5   -5          1         2
# 19     1020        -5   14.788529        -5   -5          2         2
# 20     1021        -5    9.900752        -5   -5          1         4
# 21     1022        -5    6.322526        -5   -5          2         1
# 22     1023        -5    6.924084        -5   -5          2         3
# 23     1024        -5   75.931098        -5   -5          1         4
# 24     1025        -5   14.838027        -5   -5          1         4
# 25     1026        -5   13.301551        -5   -5          1         2
# 26     1027        -5    2.801108        -5   -5          2         1
# 27     1028        -5    8.168779        -5   -5          1         4
# 28     1029        -5    3.779556        -5   -5          1         1
# 29     1030        -5   23.639174        -5   -5          1         2
# ..      ...       ...         ...       ...  ...        ...       ...
# 914    1915        -5   24.160587        -5   -5          1         3
# 915    1916        -5    3.417506        -5   -5          2         1
# 916    1917        -5    5.572501        -5   -5          1         4
# 917    1918        -5   91.225695        -5   -5          2         1
# 918    1919        -5    7.483671        -5   -5          1         2
# 919    1920        -5    6.547917        -5   -5          1         1
# 920    1921        -5    4.998309        -5   -5          1         1
# 921    1922        -5    2.293262        -5   -5          1         2
# 922    1923        -5   36.711291        -5   -5          1         4
# 923    1924        -5  104.415177        -5   -5          2         2
# 924    1925        -5   34.779217        -5   -5          1         3
# 925    1926        -5    1.180075        -5   -5          1         1
# 926    1927        -5   32.053935        -5   -5          1         1
# 927    1928        -5   14.035521        -5   -5          1         4
# 928    1929        -5    2.167571        -5   -5          1         1
# 929    1930        -5   72.331462        -5   -5          1         4
# 930    1931        -5    5.638614        -5   -5          1         2
# 931    1932        -5   24.876540        -5   -5          1         4
# 932    1933        -5   17.675037        -5   -5          1         1
# 933    1934        -5    2.487790        -5   -5          1         4
# 934    1935        -5    4.375240        -5   -5          1         2
# 935    1936        -5   11.492358        -5   -5          1         1
# 936    1937        -5   93.891391        -5   -5          2         4
# 937    1938        -5    2.730934        -5   -5          1         1
# 938    1939        -5   74.749020        -5   -5          2         2
# 939    1940        -5   11.416550        -5   -5          1         1
# 940    1941        -5    7.615180        -5   -5          1         4
# 941    1942        -5   23.761859        -5   -5          1         4
# 942    1943        -5   20.946827        -5   -5          2         4
# 943    1944        -5   11.638420        -5   -5          2         1
#
#      X1REGION  X1CENDIV  X1STATESAMPL     ...       W1SCHOOL191  W1SCHOOL192  \
# 0           3        -5            -5     ...          0.000000     0.000000
# 1           3        -5            -5     ...          0.000000     5.117174
# 2           3        -5            -5     ...          0.000000    17.768776
# 3           2        -5            -5     ...          0.000000     9.884404
# 4           3        -5            -5     ...         21.067261    12.796792
# 5           3        -5            -5     ...         16.106712     0.000000
# 6           3        -5            -5     ...          0.000000     0.000000
# 7           4        -5            -5     ...          0.000000     0.000000
# 8           3        -5            -5     ...          0.000000     0.000000
# 9           3        -5            -5     ...          0.000000    40.213143
# 10          4        -5            -5     ...          0.000000     0.000000
# 11          3        -5            -5     ...          0.000000     0.000000
# 12          3        -5            -5     ...          0.000000     0.000000
# 13          1        -5            -5     ...          0.000000    69.018053
# 14          4        -5            -5     ...         68.726587     0.000000
# 15          4        -5            -5     ...         40.450097    31.497798
# 16          2        -5            -5     ...          0.000000     7.958692
# 17          1        -5            -5     ...         12.112282    13.435486
# 18          4        -5            -5     ...          0.000000     0.000000
# 19          3        -5            -5     ...         25.851509     0.000000
# 20          4        -5            -5     ...          0.000000    10.660333
# 21          1        -5            -5     ...          9.215935     0.000000
# 22          1        -5            -5     ...         10.455293    32.337586
# 23          1        -5            -5     ...        164.286678     0.000000
# 24          3        -5            -5     ...          0.000000     0.000000
# 25          3        -5            -5     ...         14.955126    13.695953
# 26          3        -5            -5     ...          9.416605     0.000000
# 27          3        -5            -5     ...          0.000000     0.000000
# 28          2        -5            -5     ...          7.101352     0.000000
# 29          1        -5            -5     ...         39.200810     0.000000
# ..        ...       ...           ...     ...               ...          ...
# 914         3        -5            -5     ...         32.024158     0.000000
# 915         3        -5            -5     ...          0.000000     0.000000
# 916         3        -5            -5     ...          9.515974     0.000000
# 917         2        -5            -5     ...          0.000000     0.000000
# 918         3        -5            -5     ...         11.628806    14.412408
# 919         2        -5            -5     ...          0.000000    18.628691
# 920         3        -5            -5     ...         12.310493    22.831561
# 921         3        -5            -5     ...          0.000000     4.227167
# 922         3        -5            -5     ...         79.427592   101.462081
# 923         3        -5            -5     ...        130.204725     0.000000
# 924         3        -5            -5     ...          0.000000    44.499406
# 925         4        -5            -5     ...         11.976917     4.676996
# 926         2        -5            -5     ...          0.000000    44.518575
# 927         3        -5            -5     ...          0.000000     0.000000
# 928         3        -5            -5     ...          0.000000     2.832675
# 929         1        -5            -5     ...        136.805811     0.000000
# 930         2        -5            -5     ...         14.581174     0.000000
# 931         2        -5            -5     ...         45.413957    59.308965
# 932         4        -5            -5     ...         47.172631     0.000000
# 933         3        -5            -5     ...          0.000000     0.000000
# 934         2        -5            -5     ...         12.985206     0.000000
# 935         3        -5            -5     ...          0.000000     0.000000
# 936         2        -5            -5     ...        200.484634     0.000000
# 937         4        -5            -5     ...         11.642018     9.065440
# 938         3        -5            -5     ...        113.710137     0.000000
# 939         3        -5            -5     ...          0.000000     0.000000
# 940         3        -5            -5     ...          0.000000     0.000000
# 941         1        -5            -5     ...         52.447260     0.000000
# 942         2        -5            -5     ...          0.000000    12.720845
# 943         3        -5            -5     ...          0.000000     0.000000
#
#      W1SCHOOL193  W1SCHOOL194  W1SCHOOL195  W1SCHOOL196  W1SCHOOL197  \
# 0       3.601229     0.000000     5.203120     0.000000     0.000000
# 1       5.931073     0.000000     0.000000     0.000000     5.537744
# 2      13.514905    17.794190    20.618902    16.673944    24.577378
# 3       0.000000     0.000000     0.000000     6.866897    25.398480
# 4      11.042852     0.000000    22.656201    16.703235     0.000000
# 5      37.070575    12.291824     0.000000    24.603154     0.000000
# 6       0.000000     0.000000     8.821863     9.634202     0.000000
# 7       0.000000    66.149633    35.731591    30.202224     0.000000
# 8       0.000000     0.000000    25.900863     0.000000     0.000000
# 9       0.000000     0.000000     0.000000     0.000000    39.618218
# 10      0.000000    57.589998    63.991049    35.664426    37.307149
# 11      0.000000     0.000000    33.460315    29.672713     0.000000
# 12     31.545318    20.669589    29.214933    26.537850    46.640252
# 13     56.395514    80.465152    55.699196   102.688638    43.721770
# 14     56.225693     0.000000    31.060926     0.000000    32.275594
# 15     29.369043    36.533145     0.000000     0.000000    20.995468
# 16      8.156941     0.000000     0.000000     8.927220     9.572912
# 17      0.000000    21.714100    16.318347     0.000000    13.686535
# 18     17.885164    22.549626    29.857926     0.000000     0.000000
# 19     34.828024     0.000000     0.000000    55.562635     0.000000
# 20     12.559935    31.700683    18.705143     0.000000     0.000000
# 21      0.000000     0.000000     0.000000     0.000000     0.000000
# 22     48.788917    18.846776    10.643237    11.938949     0.000000
# 23      0.000000     0.000000     0.000000     0.000000     0.000000
# 24     22.503083    17.356873    15.676295    20.611228     0.000000
# 25      0.000000     0.000000     0.000000     0.000000    14.005946
# 26      0.000000     0.000000     0.000000     0.000000     0.000000
# 27      0.000000    17.666400     0.000000    15.818539    24.394286
# 28      4.948228    14.057635     7.068634     0.000000     8.698588
# 29     51.727115     0.000000     0.000000    67.564551     0.000000
# ..           ...          ...          ...          ...          ...
# 914    30.551509     0.000000    29.492682    26.396651     0.000000
# 915     0.000000    10.440900     7.613413     0.000000     7.840525
# 916     0.000000     8.531508     9.308387    10.908653    13.665650
# 917   364.229072     0.000000     0.000000     0.000000   151.621274
# 918     0.000000     0.000000    21.603797     0.000000     0.000000
# 919    14.130583    32.210624    14.913180    18.891776     0.000000
# 920    21.447078     0.000000     0.000000    15.517612     0.000000
# 921     5.511935     3.285097     5.282491     0.000000     0.000000
# 922    62.381321     0.000000    68.496910    65.013884     0.000000
# 923     0.000000   142.245834     0.000000     0.000000   145.340596
# 924    38.693082    20.086470     0.000000    23.602525     0.000000
# 925     0.000000     0.000000     4.128209     5.811411     5.333661
# 926     0.000000    91.952253     0.000000     0.000000    71.902757
# 927     0.000000    17.872318     0.000000     0.000000    22.529749
# 928     2.075514     0.000000     1.844323     2.903255     2.744479
# 929     0.000000     0.000000   115.236912   258.365322     0.000000
# 930    10.504141     0.000000    18.351836    15.246806     0.000000
# 931    41.763573     0.000000     0.000000     0.000000    71.798623
# 932     0.000000    40.031150    26.909445    27.166041    20.910796
# 933     0.000000     2.739221     4.126176     0.000000     0.000000
# 934     9.626675     0.000000    19.688258     0.000000    15.810871
# 935     0.000000    14.052230     8.777862    15.868851     0.000000
# 936     0.000000   236.195997     0.000000   211.597739     0.000000
# 937     0.000000    10.514673     9.878263     0.000000     6.042745
# 938   116.885472     0.000000     0.000000     0.000000   116.926970
# 939    11.842615    14.294814    10.622807    13.563971    17.038847
# 940     0.000000    19.889384     0.000000    17.314877    27.383467
# 941    62.207536     0.000000     0.000000     0.000000    63.511552
# 942     0.000000     0.000000     0.000000     0.000000    18.035501
# 943    32.977090    27.239670    20.390791     0.000000    32.934271
#
#      W1SCHOOL198  W1SCHOOL199  W1SCHOOL200
# 0       0.000000     0.000000     0.000000
# 1       6.027139     0.000000     0.000000
# 2       0.000000     0.000000     0.000000
# 3       6.175511    21.028035     5.663044
# 4      20.871432    22.551557     0.000000
# 5      28.206375     0.000000    11.276811
# 6       0.000000     0.000000    10.009339
# 7      33.611170     0.000000    45.937731
# 8      16.158162     0.000000     0.000000
# 9      32.134719     0.000000    28.045794
# 10      0.000000    67.503563    99.767629
# 11      0.000000     0.000000    26.127452
# 12     42.894334     0.000000    44.344387
# 13      0.000000     0.000000     0.000000
# 14      0.000000     0.000000    82.082039
# 15     27.995006     0.000000    40.007473
# 16     11.980488     7.805339     0.000000
# 17      0.000000     0.000000     8.899363
# 18     16.054916    19.236039    23.407551
# 19     46.993231     0.000000    57.947528
# 20      0.000000    30.798435    35.412170
# 21     13.340034    13.267436     0.000000
# 22      0.000000     0.000000    15.829234
# 23    173.709775   178.683849     0.000000
# 24     21.637031    23.050992     0.000000
# 25      0.000000     0.000000    10.827740
# 26      4.254942     5.479936     7.095938
# 27     23.953223     0.000000    25.474152
# 28      0.000000     0.000000     4.489166
# 29      0.000000    32.373567     0.000000
# ..           ...          ...          ...
# 914    34.457335     0.000000     0.000000
# 915     5.221215     8.866403     7.871725
# 916     0.000000    14.473224     0.000000
# 917   149.189170     0.000000   232.704500
# 918     0.000000     0.000000    11.629446
# 919     0.000000    20.551558    17.354241
# 920     0.000000     0.000000    13.347748
# 921     7.053715     0.000000     0.000000
# 922     0.000000     0.000000     0.000000
# 923     0.000000   152.662788   247.277248
# 924    38.576814    47.277329    44.625284
# 925     0.000000     0.000000     9.284944
# 926    45.608480     0.000000     0.000000
# 927     0.000000     0.000000     0.000000
# 928     0.000000     0.000000     1.492305
# 929   162.749345   163.137305   226.303819
# 930     0.000000    15.978082     8.829794
# 931    51.125625    71.060988    48.491098
# 932     0.000000    35.952506    43.756375
# 933     0.000000     0.000000     0.000000
# 934    18.968300     0.000000    10.392941
# 935     0.000000     0.000000     0.000000
# 936   212.200308     0.000000   244.266306
# 937     8.057295     9.652224    11.514626
# 938     0.000000   120.926964     0.000000
# 939    27.117139     0.000000     0.000000
# 940    24.874701     0.000000    32.787633
# 941    55.815679    53.939890    62.152353
# 942    16.690451    16.150612     0.000000
# 943     0.000000    33.351890    33.207264
#
# [944 rows x 687 columns]

# %%
student_suppressed_columns
# Out:
# ['SCH_ID',
#  'X1NCESID',
#  'X2NCESID',
#  'STRAT_ID',
#  'PSU',
#  'X1ASIAN',
#  'X1PACISLE',
#  'X1AMINDIAN',
#  'X1HISPTYPE',
#  'X1ASIANTYPE',
#  'X1NATIVELANG',
#  'X1PAR1OCC6',
#  'X1PAR1OCC_STEM2',
#  'X1PAR2OCC6',
#  'X1PAR2OCC_STEM2',
#  'X1MOMOCC6',
#  'X1MOMOCC_STEM2',
#  'X1DADOCC6',
#  'X1DADOCC_STEM2',
#  'X1STU30OCC6',
#  'X1STU30OCC_STEM2',
#  'X1STUPRVSCHL_R',
#  'X1SQINCAPABL',
#  'X1CENDIV',
#  'X1STATESAMPL',
#  'X1STATE',
#  'X1GRADESPAN',
#  'X1FREELUNCH',
#  'X1REPEAT9TH',
#  'X1SCHAMIND',
#  'X1SCHASIAN',
#  'X1SCHBLACK',
#  'X1SCHHISP',
#  'X1SCHWHITE',
#  'X2ASIAN',
#  'X2PACISLE',
#  'X2AMINDIAN',
#  'X2HISPTYPE',
#  'X2ASIANTYPE',
#  'X2NATIVELANG',
#  'X2PARRESP',
#  'X2PAR1OCC6',
#  'X2PAR1OCC_STEM2',
#  'X2PAR2OCC6',
#  'X2PAR2OCC_STEM2',
#  'X2MOMOCC6',
#  'X2MOMOCC_STEM2',
#  'X2DADOCC6',
#  'X2DADOCC_STEM2',
#  'X2STU30OCC6',
#  'X2STU30OCC_STEM2',
#  'X2SQINCAPABL',
#  'X2CENDIV',
#  'X2STATE',
#  'X2FREELUNCH',
#  'X2AQSTAT',
#  'X2AQDESIGNEE',
#  'X2CQSTAT',
#  'X3NCESID',
#  'X3CENDIV',
#  'X3STATE',
#  'X3MATCHATMPT',
#  'X3GEDSTATE',
#  'X3HSCOMPDATE',
#  'X3TLASTHS',
#  'X3TCREDAP',
#  'X3TCREDIB',
#  'X3TGPAAP',
#  'X3TGPAIB',
#  'X3TXSATMATH',
#  'X3TXSATREAD',
#  'X3TXSATCOMP',
#  'X3TXACTCOMP',
#  'X3TXPSATCOMP',
#  'X3TXPSATMATH',
#  'X3TXPSATREAD',
#  'X3TXPSATWRIT',
#  'X3TXAPARTHI',
#  'X3TXAPMUSIC',
#  'X3TXAPART2D',
#  'X3TXAPART3D',
#  'X3TXAPARTDR',
#  'X3TXAPENGLNG',
#  'X3TXAPENGLIT',
#  'X3TXAPCMPGOV',
#  'X3TXAPEURO',
#  'X3TXAPHUGEO',
#  'X3TXAPMACRO',
#  'X3TXAPMICRO',
#  'X3TXAPPSYCH',
#  'X3TXAPUSGOV',
#  'X3TXAPUSHIST',
#  'X3TXAPWOHIST',
#  'X3TXAPMATCOM',
#  'X3TXAPCALCAB',
#  'X3TXAPCALCBC',
#  'X3TXAPCOMSCI',
#  'X3TXAPSTATS',
#  'X3TXAPBIO',
#  'X3TXAPCHEM',
#  'X3TXAPENVSCI',
#  'X3TXAPPHYB',
#  'X3TXAPPHYELE',
#  'X3TXAPPHYMEC',
#  'X3TXAPCHI',
#  'X3TXAPFRE',
#  'X3TXAPGER',
#  'X3TXAPITL',
#  'X3TXAPJAP',
#  'X3TXAPLAT',
#  'X3TXAPSPLANG',
#  'X3TXAPSPLIT',
#  'X3TXSATLIT',
#  'X3TXSATUSH',
#  'X3TXSATWOH',
#  'X3TXSATMAT1',
#  'X3TXSATMAT2',
#  'X3TXSATBIO',
#  'X3TXSATCHE',
#  'X3TXSATPHY',
#  'X3TXSATFRE',
#  'X3TXSATFREL',
#  'X3TXSATGER',
#  'X3TXSATGERL',
#  'X3TXSATSPA',
#  'X3TXSATSPAL',
#  'X3TXSATHEB',
#  'X3TXSATITL',
#  'X3TXSATLAT',
#  'X3TXSATCHIL',
#  'X3TXSATJAPL',
#  'X3TXSATKORL',
#  'X4NCESID',
#  'X4STATE',
#  'X4CENDIV',
#  'X4TXSATMATH',
#  'X4TXSATREAD',
#  'X4TXSATCOMP',
#  'X4TXACTCOMP',
#  'X4GEDDATE',
#  'X4GEDSTATE',
#  'X4CHOICEAPPID',
#  'X4CHOICEACCID',
#  'X4ATNDAPPINST',
#  'X4PS1',
#  'X4REFINST',
#  'X4REFDEG',
#  'X4RFDGMJ16',
#  'X4RFDGMJ26',
#  'X4RFDGMJ22',
#  'X4OCCFB6',
#  'X4OCCFBSTEM2',
#  'X4OCCFBMRST2',
#  'X4OCC1STEM2',
#  'X4STU30OCC6',
#  'X4OCC30STEM2',
#  'X4IMMIGEN',
#  'X4GENDERID',
#  'X4MATCHATMPT',
#  'X4GEDMATCH',
#  'X4NSLDSSTAT',
#  'X4CPS1314STAT',
#  'X4CPS1415STAT',
#  'X4CPS1516STAT',
#  'X4CPS1617STAT',
#  'X4CPS1718STAT',
#  'S1HISPANIC',
#  'S1HISPOR',
#  'S1WHITE',
#  'S1BLACK',
#  'S1ASIAN',
#  'S1PACISLE',
#  'S1AMINDIAN',
#  'S1ASIANOR',
#  'S1LANG1STOS',
#  'S1ANATOMYS09',
#  'S1ADVCHEMS09',
#  'S1TECHS09',
#  'S1COSTPRV',
#  'S1COSTOUT',
#  'S1OCC30',
#  'S2HSID',
#  'S2CURCONTROL',
#  'S2CURLOCALE',
#  'S2CURREGION',
#  'S2CURCENDIV',
#  'S2CURSTATE',
#  'S2HSCREDMO',
#  'S2LASTATTEND',
#  'S2LASTHSID',
#  'S2LASTCONTROL',
#  'S2LASTLOCALE',
#  'S2LASTREGION',
#  'S2LASTCENDIV',
#  'S2LASTSTATE',
#  'S2OTHHSID1',
#  'S2OTH1CONTROL',
#  'S2OTH1LOCALE',
#  'S2OTH1REGION',
#  'S2OTH1CENDIV',
#  'S2OTH1STATE',
#  'S2OTHHSID2',
#  'S2OTH2CONTROL',
#  'S2OTH2LOCALE',
#  'S2OTH2REGION',
#  'S2OTH2CENDIV',
#  'S2OTH2STATE',
#  'S2ENROCCTRN',
#  'S2ENR2YPUB',
#  'S2ENR4Y',
#  'S2HISPANIC',
#  'S2HISPOR',
#  'S2WHITE',
#  'S2BLACK',
#  'S2ASIAN',
#  'S2PACISLE',
#  'S2AMINDIAN',
#  'S2ASIANOR',
#  'S2LANG1STOS',
#  'S2PARREL1',
#  'S2JOBDV1',
#  'S2JOBTV1',
#  'S2JOB2ONET1',
#  'S2JOB6ONET1',
#  'S2JOBONET1_STEM2',
#  'S2PARREL2',
#  'S2JOBDV2',
#  'S2JOBTV2',
#  'S2JOB2ONET2',
#  'S2JOB6ONET2',
#  'S2JOBONET2_STEM2',
#  'S2LIKELYCLGID',
#  'S2CHOICECLGID',
#  'S2EARNNOHS',
#  'S2EARNNOHSUN',
#  'S2EARNHS',
#  'S2EARNHSUN',
#  'S2EARNOCC',
#  'S2EARNOCCUN',
#  'S2EARN2YPUB',
#  'S2EARN2YPUBUN',
#  'S2EARN4Y',
#  'S2EARN4YUN',
#  'S2OCC30',
#  'S2IBMATHSTD12',
#  'S2IBMATHHI12',
#  'S2OTHM12SP',
#  'S2IBENVS12',
#  'S2TECHS12',
#  'S2IBTECH12',
#  'S2OTHS12',
#  'S2OTHS12SP',
#  'S2JOBMO',
#  'S2JOBEARN',
#  'S2JOBUNIT',
#  'S2JOBLEFTRSN',
#  'S2CHILDBORNMO',
#  'S2LIVECHILD',
#  'S2LIVESPOUSE',
#  'S2LIVEALONE',
#  'S3HSCREDMO',
#  'S3HSCOMPMO',
#  'S3LASTHSMO',
#  'S3LASTHSID',
#  'S3LASTCONTROL',
#  'S3LASTLOCALE',
#  'S3LASTREGION',
#  'S3LASTCENDIV',
#  'S3LASTSTATE',
#  'S3OTHHSID1',
#  'S3OTH1CONTROL',
#  'S3OTH1LOCALE',
#  'S3OTH1REGION',
#  'S3OTH1CENDIV',
#  'S3OTH1STATE',
#  'S3OTHHSID2',
#  'S3OTH2CONTROL',
#  'S3OTH2LOCALE',
#  'S3OTH2REGION',
#  'S3OTH2CENDIV',
#  'S3OTH2STATE',
#  'S3CLGID',
#  'S3CLGSTATE',
#  'S3FIELD',
#  'S3FIELD6',
#  'S3CLGAPPID1',
#  'S3CLGAPPSTATE1',
#  'S3CLGAPPID2',
#  'S3CLGAPPSTATE2',
#  'S3CHOICEAPPID',
#  'S3CHOICEAPPSTATE',
#  'S3CHOICEACCID',
#  'S3CHOICEACCSTATE',
#  'S3CURJOBTTL',
#  'S3CURJOBDUT',
#  'S3CURJOB6',
#  'S3CURJOB_STEM2',
#  'S3CURJOBEARN',
#  'S3CURJOBUNIT',
#  'S3CURWKSPERMO',
#  'S3CURWKSPERYR',
#  'S3OTHJOBEARN',
#  'S3OTHJOBUNIT',
#  'S3OTHWKSPERMO',
#  'S3OTHWKSPERYR',
#  'S3NOV1JOBTTL',
#  'S3NOV1JOBDUT',
#  'S3NOV1JOB6',
#  'S3NOV1JOB_STEM2',
#  'S3FALLHSID',
#  'S3FALLCONTROL',
#  'S3FALLLOCALE',
#  'S3FALLREGION',
#  'S3FALLCENDIV',
#  'S3FALLSTATE',
#  'S4HSCREDMO',
#  'S4GEDSTATE',
#  'S4LASTHSMO',
#  'S4LASTHSID',
#  'S4LASTHSCENDIV',
#  'S4LASTHSSTATE',
#  'S4ALG1WHEN',
#  'S4CLGAPPNUM',
#  'S4CLGID',
#  'S4CLGAPPID1',
#  'S4CLGAPPID2',
#  'S4CHOICEAPPID',
#  'S4CHOICEAPPID_I',
#  'S4CHOICEACCID',
#  'S4CHOICEACCID_I',
#  'S4FIELD',
#  'S4FIELD6',
#  'S4PRVLOANAMT',
#  'S4MLTSTARTM',
#  'S4MLTENDM',
#  'S4MLTENDY',
#  'S4COASTGRD',
#  'S4JOBTITLE1',
#  'S4JOBDUTY1',
#  'S4JOB61',
#  'S4JOBTITLE2',
#  'S4JOBTITLE2_I',
#  'S4JOBDUTY2',
#  'S4JOBDUTY2_I',
#  'S4JOB22',
#  'S4JOB22_I',
#  'S4JOB62',
#  'S4JOB62_I',
#  'S4OCC30',
#  'S4MARRIAGEM',
#  'S4BIOCHILDNUM',
#  'S4BIOCHILDNUM_I',
#  'S4ADPTCHILDNUM',
#  'S4ADPTCHILDNUM_I',
#  'S4STEPCHILDNUM',
#  'S4STEPCHILDNUM_I',
#  'S4CHILDBORNM',
#  'S4CHILDBORNY',
#  'S4ADOPTM',
#  'S4ADOPTY',
#  'S4STEPPARM',
#  'S4STEPPARY',
#  'S4ZIP16FB',
#  'S4INCOME',
#  'S4INCOMECAT',
#  'S4INCOMECAT_I',
#  'S4INCOMESPS',
#  'S4INCOMESPCAT',
#  'S4INCOMESPCAT_I',
#  'S4USBORN',
#  'S4CITIZEN',
#  'S4BIRTHSEX',
#  'S4MALE',
#  'S4FEMALE',
#  'S4TRANSMTF',
#  'S4TRANSFTM',
#  'S4OTHGENDER',
#  'S4DKGENDER',
#  'S4ORIENTATION',
#  'P1HHPARREL1',
#  'P1HHPARREL2',
#  'P1HHLT18',
#  'P1HHGE18',
#  'P1HISP1',
#  'P1HISPOR1',
#  'P1WHITE1',
#  'P1BLACK1',
#  'P1ASIAN1',
#  'P1PACISLE1',
#  'P1AMINDIAN1',
#  'P1ASIANOR1',
#  'P1COUNTRY1',
#  'P1HISP2',
#  'P1HISPOR2',
#  'P1WHITE2',
#  'P1BLACK2',
#  'P1ASIAN2',
#  'P1PACISLE2',
#  'P1AMINDIAN2',
#  'P1ASIANOR2',
#  'P1COUNTRY2',
#  'P1COUNTRY9',
#  'P1SPANISH',
#  'P1EUROLANG',
#  'P1CHINESE',
#  'P1FILIPINO',
#  'P1SEASIAN',
#  'P1SASIAN',
#  'P1OTHRASIAN',
#  'P1MIDEAST',
#  'P1OTHRLANG',
#  'P1RSPLANG',
#  'P1LANG9',
#  'P1HIMAJV1',
#  'P1HIMAJ61',
#  'P1BAMAJV1',
#  'P1BAMAJ61',
#  'P1JOB6ONET1',
#  'P1JOBONET1_STEM2',
#  'P1JOBDV1',
#  'P1JOBTV1',
#  'P1HIMAJV2',
#  'P1HIMAJ62',
#  'P1BAMAJV2',
#  'P1BAMAJ62',
#  'P1JOB6ONET2',
#  'P1JOBONET2_STEM2',
#  'P1JOBDV2',
#  'P1JOBTV2',
#  'P1INCOME',
#  'P1SKIPG4',
#  'P1SKIPG5',
#  'P1SKIPG6',
#  'P1SKIPG7',
#  'P1COSTPRV',
#  'P1COSTOUT',
#  'P1QHELP3',
#  'P2RELSHP',
#  'P2HHPARREL1',
#  'P2HHPARREL2',
#  'P2SPSREL',
#  'P2OTHREL',
#  'P2HHLT18',
#  'P2HHGE18',
#  'P2SKIPGK',
#  'P2SKIPG1',
#  'P2SKIPG2',
#  'P2SKIPG3',
#  'P2SKIPG4',
#  'P2SKIPG5',
#  'P2SKIPG6',
#  'P2SKIPG7',
#  'P2SKIPG8',
#  'P2SKIPG10',
#  'P2SKIPG11',
#  'P2HSDIPGED',
#  'P2LIKELYCLGID',
#  'P2CHOICECLGID',
#  'P2EARNNOHS',
#  'P2EARNNOHSUN',
#  'P2EARNHS',
#  'P2EARNHSUN',
#  'P2EARNOCC',
#  'P2EARNOCCUN',
#  'P2EARN2YPUB',
#  'P2EARN2YPUBUN',
#  'P2EARN4Y',
#  'P2EARN4YUN',
#  'P2HIMAJV1',
#  'P2HIMAJ61',
#  'P2JOBDV1',
#  'P2JOBTV1',
#  'P2JOB2ONET1',
#  'P2JOB6ONET1',
#  'P2JOBONET1_STEM2',
#  'P2HIMAJV2',
#  'P2HIMAJ62',
#  'P2JOBDV2',
#  'P2JOBTV2',
#  'P2JOB2ONET2',
#  'P2JOB6ONET2',
#  'P2JOBONET2_STEM2',
#  'P2INCOME',
#  'P2INCOMECAT',
#  'P2HISP1',
#  'P2HISPOR1',
#  'P2WHITE1',
#  'P2BLACK1',
#  'P2ASIAN1',
#  'P2PACISLE1',
#  'P2AMINDIAN1',
#  'P2ASIANOR1',
#  'P2HISP2',
#  'P2HISPOR2',
#  'P2WHITE2',
#  'P2BLACK2',
#  'P2ASIAN2',
#  'P2PACISLE2',
#  'P2AMINDIAN2',
#  'P2ASIANOR2',
#  'P2COUNTRYT',
#  'P2SPANISH',
#  'P2EUROLANG',
#  'P2CHINESE',
#  'P2FILIPINO',
#  'P2SEASIAN',
#  'P2SASIAN',
#  'P2OTHRASIAN',
#  'P2MIDEAST',
#  'P2OTHRLANG',
#  'P2RSPLANG',
#  'P2LANGTEEN',
#  'P2QHELP3',
#  'M1HISP',
#  'M1WHITE',
#  'M1BLACK',
#  'M1ASIAN',
#  'M1PACISLE',
#  'M1AMINDIAN',
#  'M1HIDEGIPEDS',
#  'M1HIDEGST',
#  'M1HIDEGLEVEL',
#  'M1HIMAJV',
#  'M1HIMAJ6',
#  'M1BAIPEDS',
#  'M1BAST',
#  'M1BALEVEL',
#  'M1BAMAJV',
#  'M1BAMAJ6',
#  'N1HISP',
#  'N1WHITE',
#  'N1BLACK',
#  'N1ASIAN',
#  'N1PACISLE',
#  'N1AMINDIAN',
#  'N1HIDEGIPEDS',
#  'N1HIDEGST',
#  'N1HIDEGLEVEL',
#  'N1HIMAJV',
#  'N1HIMAJ6',
#  'N1BAIPEDS',
#  'N1BAST',
#  'N1BALEVEL',
#  'N1BAMAJV',
#  'N1BAMAJ6',
#  'A1GRADEPREK',
#  'A1GRADEK',
#  'A1GRADE1',
#  'A1GRADE2',
#  'A1GRADE3',
#  'A1GRADE4',
#  'A1GRADE5',
#  'A1GRADE6',
#  'A1GRADE7',
#  'A1GRADE8',
#  'A1GRADE9',
#  'A1GRADE10',
#  'A1GRADE11',
#  'A1GRADE12',
#  'A1GRADE13',
#  'A1UNGRADED',
#  'A1RELIGIOUS',
#  'A1RELIGTYPE',
#  'A1SINGLESEX',
#  'A1SCHTYPE',
#  'A1SCHSPFOCUS',
#  'A1CHOICEPROG',
#  'A1CHOICEIN',
#  'A1CHOICEOUT',
#  'A1CHOICESCH',
#  'A1CHOICEPRIV',
#  'A1CHOICEOTHR',
#  'A1YRROUND',
#  'A1CALENDAR',
#  'A1SCHEDULE',
#  'A1TRADMINS',
#  'A1ACADBLOCK',
#  'A1VOCBLOCK',
#  'A1OTHRBLOCK',
#  'A1ABLOCKMINS',
#  'A1VBLOCKMINS',
#  'A1OBLOCKMINS',
#  'A1CLASSHRS',
#  'A1ADA',
#  'A1TRANSFRALT',
#  'A1AYP',
#  'A1AYPYR',
#  'A1MADEAYP',
#  'A1MESA',
#  'A1G9TUTOR',
#  'A1G9NOPROG',
#  'A1CAPACITY',
#  'A1OFFERALT',
#  'A1OFFERAP',
#  'A1FREELUNCH',
#  'A1ELL',
#  'A1SPECIALED',
#  'A1ALTPROG',
#  'A1DROPOUTPRV',
#  'A1AP',
#  'A1HISPSTU',
#  'A1WHITESTU',
#  'A1BLACKSTU',
#  'A1ASIANPISTU',
#  'A1AMINDIANST',
#  'A1REPEATG9',
#  'A1RETURN09',
#  'A14YRDEGREE',
#  'A12YRDEGREE',
#  'A1WORK',
#  'A1MILITARY',
#  'A1DIDOTHER',
#  'A1FTTCHRS',
#  'A1PTTCHRS',
#  'A1FTMTCHRS',
#  'A1PTMTCHRS',
#  'A1FTSTCHRS',
#  'A1PSCTCHRS',
#  'A1FTOTHTCHRS',
#  'A1PTOTHTCHRS',
#  'A1CERTFTMTCH',
#  'A1CERTPTMTCH',
#  'A1CERTFTSTCH',
#  'A1CERTPTSTCH',
#  'A1MSRECRUIT',
#  'A1MINCENTIVE',
#  'A1SINCENTIVE',
#  'A1MTNORETURN',
#  'A1STNORETURN',
#  'A1ABSENTTCHR',
#  'A1ONPREALG',
#  'A1ONRMTH',
#  'A1ONINTMTH1',
#  'A1ONINTMTH2',
#  'A1ONALGP1P2',
#  'A1ONALG1',
#  'A1ONALG2',
#  'A1ONGEOM',
#  'A1ONTRIG',
#  'A1ONALG3',
#  'A1ONANGEOM',
#  'A1ONCLC',
#  'A1ONCLCAPAB',
#  'A1ONCLCAPBC',
#  'A1ONCLCAPIB',
#  'A1ONCMPSCI',
#  'A1ONCMPSCIA',
#  'A1ONCMPSCIB',
#  'A1ONSTATS',
#  'A1ONSTATSAP',
#  'A1OFFPREALG',
#  'A1OFFRMTH',
#  'A1OFFINTMTH1',
#  'A1OFFINTMTH2',
#  'A1OFFALGP1P2',
#  'A1OFFALG1',
#  'A1OFFALG2',
#  'A1OFFGEOM',
#  'A1OFFTRIG',
#  'A1OFFALG3',
#  'A1OFFANGEOM',
#  'A1OFFCLC',
#  'A1OFFCLCAPAB',
#  'A1OFFCLCAPBC',
#  'A1OFFCMPSCI',
#  'A1OFFCLCAPIB',
#  'A1OFFMPSCIA',
#  'A1OFFCMPSCIB',
#  'A1OFFSTATS',
#  'A1OFFSTATSAP',
#  'A1NOMTHO',
#  'A1ONGENSCI',
#  'A1ONPHYSCI',
#  'A1ONERTHSCI',
#  'A1ONENVSCI',
#  'A1ONTECH',
#  'A1ONBIO1',
#  'A1ONLIFESCI',
#  'A1ONCHEM1',
#  'A1ONPHYS1',
#  'A1ONINTGSCI1',
#  'A1ONINTGSCI2',
#  'A1ONANATOMY',
#  'A1ONENVAP',
#  'A1ONADVBIO',
#  'A1ONADVCHEM',
#  'A1ONADVPHYS',
#  'A1ONOTHBIO',
#  'A1ONOTHPSCI',
#  'A1ONOTHESCI',
#  'A1OFFGENSCI',
#  'A1OFFPHYSCI',
#  'A1OFFERTHSCI',
#  'A1OFFTECH',
#  'A1OFFBIO1',
#  'A1OFFLSCI',
#  'A1OFFCHEM1',
#  'A1OFFPHYS1',
#  'A1OFFINTSCI1',
#  'A1OFFINTSCI2',
#  'A1OFFENVSCI',
#  'A1OFFANATOMY',
#  'A1OFFENVAP',
#  'A1OFFADVBIO',
#  'A1OFFADVCHEM',
#  'A1OFFADVPHYS',
#  'A1OFFOTHPSCI',
#  'A1OFFOTHBIO',
#  'A1OFFOTHESCI',
#  'A1NOSCIO',
#  'A1IB',
#  'A1MTHREQS',
#  'A1MTHSTREQ',
#  'A1SCIREQS',
#  'A1SCISTREQ',
#  'A1SEX',
#  'A1HISP',
#  'A1WHITE',
#  'A1BLACK',
#  'A1ASIAN',
#  'A1PACISLE',
#  'A1AMINDIAN',
#  'A1HIDEG',
#  'A1HIMAJV',
#  'A1HIMAJ2',
#  'A1HIMAJ6',
#  'A1BAMAJV',
#  'A1BAMAJ2',
#  'A1BAMAJ6',
#  'A1STARTDEG',
#  'A1MANAGEMENT',
#  'A1ALTPREP',
#  'A1CERTIFIED',
#  'A1YRSHSLSSCH',
#  'A1TEACHING',
#  'A1YRSMSTCHR',
#  'A1YRSHSTCHR',
#  'A1MSSUBJECT',
#  'A1HSSUBJECT',
#  'A1HRDISCIPLN',
#  'A1STUABSENT',
#  'A1CUT',
#  'A1DROPOUT',
#  'A1CONFLICT',
#  'A1ROBBERY',
#  'A1VANDALISM',
#  'A1DRUGUSE',
#  'A1ALCOHOL',
#  'A1DRUGSALE',
#  'A1WEAPONS',
#  'A1PHYSABUSE',
#  'A1TENSION',
#  'A1BULLY',
#  'A1VERBAL',
#  'A1MISBEHAVE',
#  'A1DISRESPECT',
#  'A1GANG',
#  'A2SCHTYPE',
#  'A2MAGNET',
#  'A2STEMFOCUS',
#  'A2CHOICEIN',
#  'A2CHOICEOUT',
#  'A2CHOICESCH',
#  'A2CHOICEPRIV',
#  'A2YRROUND',
#  'A2CALENDAR',
#  'A2CLASSHRS',
#  'A2HRSINSMIN',
#  'A2SCHEDULE',
#  'A2CAPACITY',
#  'A2FREELUNCH',
#  'A2ELL',
#  'A2SPECIALED',
#  'A2TRANSFRALT',
#  'A2FTTCHRS',
#  'A2PTTCHRS',
#  'A2FTMTCHRS',
#  'A2PTMTCHRS',
#  'A2FTSTCHRS',
#  'A2FTOTHTCHRS',
#  'A2PTOTHTCHRS',
#  'A2PENSION',
#  'A2MTNORETURN',
#  'A2STNORETURN',
#  'A2ABSENTTCHR',
#  'A2STUABSENT',
#  'A2CUT',
#  'A2DROPOUT',
#  'A2CONFLICT',
#  'A2ROBBERY',
#  'A2VANDALISM',
#  'A2DRUGUSE',
#  'A2ALCOHOL',
#  'A2DRUGSALE',
#  'A2WEAPONS',
#  'A2PHYSABUSE',
#  'A2TENSION',
#  'A2VERBAL',
#  'A2MISBEHAVE',
#  'A2DISRESPECT',
#  'A2GANG',
#  'A2SEX',
#  'A2HISP',
#  'A2WHITE',
#  'A2BLACK',
#  'A2ASIAN',
#  'A2PACISLE',
#  'A2AMINDIAN',
#  'A2HIDEG',
#  'A2HIMAJV',
#  'A2HIMAJ2',
#  'A2HIMAJ6',
#  'A2BAMAJV',
#  'A2BAMAJ2',
#  'A2BAMAJ6',
#  'A2MANAGEMENT',
#  'A2ALTPREP',
#  'A2CERTIFIED',
#  'A2YRSHSLSSCH',
#  'A2TEACHING',
#  'A2YRSMSTCHR',
#  'A2YRSHSTCHR',
#  'A2TCHSUBJO',
#  'C1FTCNSL',
#  'C1PTCNSL',
#  'C1FTCERTCNSL',
#  'C1PTCERTCNSL',
#  'C1DISCIPLINE',
#  'C1G9LOWEST',
#  'C1TRANNONE',
#  'C1STAFFENRCH',
#  'C1ENRICHMENT',
#  'C1APCOURSE',
#  'C1NOSUPPORT',
#  'C1GETAHEAD',
#  'C1STRUGGLE',
#  'C1AVERAGE',
#  'C1HIGH',
#  'C1TUTOR',
#  'C1NOASSIST',
#  'C1INDEPSTUDY',
#  'C1TECH',
#  'C1MRETAKE',
#  'C1MREMEDL',
#  'C1MREPEAT',
#  'C1MTSTPREP',
#  'C1MTUTOR',
#  'C1MINDPRG',
#  'C1MSUMSCH',
#  'C1MALTSCH',
#  'C1UPBOUND',
#  'C1DUALENROLL',
#  'C1BEHAVIOR',
#  'C1NOSTEPS',
#  'C1CTE',
#  'C1DECISION',
#  'C1VOCTECH',
#  'C1JOBSIM',
#  'C1JOBSKILLS',
#  'C1YRSK12',
#  'C1YRS912',
#  'C1HIDEG',
#  'C1HIMAJV',
#  'C1HIMAJ2',
#  'C1HIMAJ6',
#  'C1BAMAJV',
#  'C1BAMAJ2',
#  'C1BAMAJ6',
#  'C1INCDEG',
#  'C1ENTRY',
#  'C2FTCNSL',
#  'C2PTCNSL',
#  'C2DUALCLGCRED',
#  'C2DUALENRACA',
#  'C2DUALENRCTE',
#  'C2DUALGRAD',
#  'C2GETAHEAD',
#  'C2UPBOUND',
#  'C2CLGEXAMINFO',
#  'C2CLGINFO',
#  'C2NUMAPEXAM',
#  'C2NUMAP3PLUS',
#  'C2NUMIBEXAM',
#  'C2NUMIB4PLUS',
#  'C2NUMAPANDIB',
#  'X1NATIVEL_IM',
#  'X2NATIVEL_IM']
